# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

# New Antecedent/Consequent objects hold universe variables and membership
# functions
humedad = ctrl.Antecedent(np.arange(0, 1024, 1), 'humedad')
temperatura_ambiental = ctrl.Antecedent(np.arange(-5, 46, 1), 'temperatura_ambiental')
humedad_ambiental = ctrl.Antecedent(np.arange(0, 101, 1), 'humedad_ambiental')
tiempo_riego = ctrl.Consequent(np.arange(0, 17, 1), 'tiempo_riego')

# Auto-membership function population is possible with .automf(3, 5, or 7)
humedad['seco'] = fuzz.trimf(humedad.universe, [0, 100, 200])
humedad['semi_seco'] = fuzz.trimf(humedad.universe, [120, 310, 500])
humedad['humedo'] = fuzz.trimf(humedad.universe, [450, 572, 694])
humedad['semi_humedo'] = fuzz.trimf(humedad.universe, [658, 725, 792])
humedad['encharcado'] = fuzz.trimf(humedad.universe, [750, 825, 900])

temperatura_ambiental['baja'] = fuzz.trimf(temperatura_ambiental.universe, [-5, 2, 10])
temperatura_ambiental['media'] = fuzz.trimf(temperatura_ambiental.universe, [2, 17, 27])
temperatura_ambiental['alta'] = fuzz.trimf(temperatura_ambiental.universe, [24, 34, 45])

humedad_ambiental['baja'] = fuzz.trimf(humedad_ambiental.universe, [0, 16, 33])
humedad_ambiental['media'] = fuzz.trimf(humedad_ambiental.universe, [16, 41, 66])
humedad_ambiental['alta'] = fuzz.trimf(humedad_ambiental.universe, [41, 70, 100])

# Custom membership functions can be built interactively with a familiar,
# Pythonic API
tiempo_riego['nada'] = fuzz.trimf(tiempo_riego.universe, [0, 0, 0])
tiempo_riego['poco'] = fuzz.trimf(tiempo_riego.universe, [0, 2 , 4])
tiempo_riego['medio'] = fuzz.trimf(tiempo_riego.universe, [3, 6, 9])
tiempo_riego['bastante'] = fuzz.trimf(tiempo_riego.universe, [7, 9, 12])
tiempo_riego['mucho'] = fuzz.trapmf(tiempo_riego.universe, [10, 13, 17, 17])

# %%
# You can see how these look with .view()
humedad.view()
# Out:
# C:\casa-ortiz\django\smartnature\venv\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
temperatura_ambiental.view()
# Out:
# C:\casa-ortiz\django\smartnature\venv\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
humedad_ambiental.view()
# Out:
# C:\casa-ortiz\django\smartnature\venv\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
tiempo_riego.view()
# Out:
# C:\casa-ortiz\django\smartnature\venv\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
rule1 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['baja'] & humedad_ambiental['baja'], tiempo_riego['nada'])
rule2 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['baja'] & humedad_ambiental['media'], tiempo_riego['nada'])
rule3 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['baja'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule4 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['media'] & humedad_ambiental['baja'], tiempo_riego['nada'])
rule5 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['media'] & humedad_ambiental['media'], tiempo_riego['nada'])
rule6 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['media'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule7 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['alta'] & humedad_ambiental['baja'], tiempo_riego['nada'])
rule8 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['alta'] & humedad_ambiental['media'], tiempo_riego['nada'])
rule9 = ctrl.Rule(humedad['encharcado'] & temperatura_ambiental['alta'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule10 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['baja'] & humedad_ambiental['baja'], tiempo_riego['nada'])
rule11 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['baja'] & humedad_ambiental['media'], tiempo_riego['nada'])
rule12 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['baja'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule13 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['media'] & humedad_ambiental['baja'], tiempo_riego['poco'])
rule14 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['media'] & humedad_ambiental['media'], tiempo_riego['nada'])
rule15 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['media'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule16 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['alta'] & humedad_ambiental['baja'], tiempo_riego['medio'])
rule17 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['alta'] & humedad_ambiental['media'], tiempo_riego['poco'])
rule18 = ctrl.Rule(humedad['semi_humedo'] & temperatura_ambiental['alta'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule19 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['baja'] & humedad_ambiental['baja'], tiempo_riego['nada'])
rule20 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['baja'] & humedad_ambiental['media'], tiempo_riego['nada'])
rule21 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['baja'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule22 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['media'] & humedad_ambiental['baja'], tiempo_riego['poco'])
rule23 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['media'] & humedad_ambiental['media'], tiempo_riego['poco'])
rule24 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['media'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule25 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['alta'] & humedad_ambiental['baja'], tiempo_riego['medio'])
rule26 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['alta'] & humedad_ambiental['media'], tiempo_riego['poco'])
rule27 = ctrl.Rule(humedad['humedo'] & temperatura_ambiental['alta'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule28 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['baja'] & humedad_ambiental['baja'], tiempo_riego['poco'])
rule29 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['baja'] & humedad_ambiental['media'], tiempo_riego['nada'])
rule30 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['baja'] & humedad_ambiental['alta'], tiempo_riego['nada'])
rule31 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['media'] & humedad_ambiental['baja'], tiempo_riego['bastante'])
rule32 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['media'] & humedad_ambiental['media'], tiempo_riego['medio'])
rule33 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['media'] & humedad_ambiental['alta'], tiempo_riego['poco'])
rule34 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['alta'] & humedad_ambiental['baja'], tiempo_riego['mucho'])
rule35 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['alta'] & humedad_ambiental['media'], tiempo_riego['bastante'])
rule36 = ctrl.Rule(humedad['semi_seco'] & temperatura_ambiental['alta'] & humedad_ambiental['alta'], tiempo_riego['mucho'])
rule37 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['baja'] & humedad_ambiental['baja'], tiempo_riego['medio'])
rule38 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['baja'] & humedad_ambiental['media'], tiempo_riego['medio'])
rule39 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['baja'] & humedad_ambiental['alta'], tiempo_riego['poco'])
rule40 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['media'] & humedad_ambiental['baja'], tiempo_riego['mucho'])
rule41 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['media'] & humedad_ambiental['media'], tiempo_riego['mucho'])
rule42 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['media'] & humedad_ambiental['alta'], tiempo_riego['bastante'])
rule43 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['alta'] & humedad_ambiental['baja'], tiempo_riego['mucho'])
rule44 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['alta'] & humedad_ambiental['media'], tiempo_riego['mucho'])
rule45 = ctrl.Rule(humedad['seco'] & temperatura_ambiental['alta'] & humedad_ambiental['alta'], tiempo_riego['mucho'])

rule1.view()
# Out:
# (<Figure size 432x288 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ## Control System Creation and Simulation.
#
# Now that we have our rules defined, we can simply create a control system via:

# %%
tipping_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,
rule17,rule18,rule19,rule20,rule21,rule22,rule23,rule24,rule25,rule26,rule27,rule28,rule29,rule30,rule31,rule32,rule33,rule34,rule3,rule36,
rule37,rule38,rule39,rule40,rule41,rule42,rule43,rule44,rule45])

# %% [markdown]
# In order to simulate this control system, we will create a ControlSystemSimulation.
# Think of this object representing our controller applied to a specific set of cirucmstances.
# For tipping, this might be tipping Sharon at the local brew-pub.
# We would create another ControlSystemSimulation when we’re trying to apply our tipping_ctrl for Travis at the cafe because the inputs would be different.

# %%
tipping = ctrl.ControlSystemSimulation(tipping_ctrl)

# %% [markdown]
# We can now simulate our control system by simply specifying the inputs and calling the compute method. Suppose we rated the quality 6.5 out of 10 and the service 9.8 of 10.

# %%
# Pass inputs to the ControlSystem using Antecedent labels with Pythonic API
# Note: if you like passing many inputs all at once, use .inputs(dict_of_data)
tipping.input['humedad'] = 2
tipping.input['humedad_ambiental'] = 29
tipping.input['temperatura_ambiental'] = 35

# Crunch the numbers
tipping.compute()
# Out:
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:53:54 -05)" skipped: maximum number of running instances reached (1)

# %% [markdown]
# Once computed, we can view the result as well as visualize it.

# %%
print (tipping.output['tiempo_riego'])
tiempo_riego.view(sim=tipping)
# Out:
# 13.01497487437186
# C:\casa-ortiz\django\smartnature\venv\lib\site-packages\skfuzzy\control\fuzzyvariable.py:122: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:53:59 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:04 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:09 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:14 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:19 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:24 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:29 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:34 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:39 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:44 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:49 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:54 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:54:59 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:04 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:09 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:14 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:19 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:24 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:29 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:34 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:39 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:44 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:49 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:54 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:55:59 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:04 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:09 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:14 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:19 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:24 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:29 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:34 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:39 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:44 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:49 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:54 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:56:59 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:04 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:09 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:14 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:19 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:24 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:29 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:34 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:39 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:44 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:49 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:54 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:57:59 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:04 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:09 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:14 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:19 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:24 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:29 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:34 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:39 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:44 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:49 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:54 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:58:59 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:04 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:09 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:14 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:19 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:24 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:29 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:34 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:39 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:44 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:49 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:54 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 10:59:59 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:04 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:09 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:14 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:19 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:24 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:29 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:34 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:39 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:44 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:49 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:54 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:00:59 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:04 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:09 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:14 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:19 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:24 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:29 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:34 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:39 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:44 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:49 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:54 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:01:59 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:04 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:09 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:14 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:19 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:24 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:29 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:34 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:39 -05)" skipped: maximum number of running instances reached (1)
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:44 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:49 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:54 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:02:59 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
# soy otra tarea
# {'horario1': '19:38', 'horario2': '21:09'}
# False
# 2020-11-22 11:02:59.458997
# False
# 2020-11-22 11:02:59.458997
# {'horario1': '19:38', 'horario2': '21:09'}
# False
# 2020-11-22 11:03:04.468191
# False
# 2020-11-22 11:03:04.469198
# {'horario1': '19:38', 'horario2': '21:09'}
# False
# 2020-11-22 11:03:09.385366
# False
# 2020-11-22 11:03:09.385366
# {'horario1': '19:38', 'horario2': '21:09'}
# False
# 2020-11-22 11:03:14.397270
# False
# 2020-11-22 11:03:14.397270
# soy otra tarea
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:03:24 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:03:29 -05)" skipped: maximum number of running instances reached (1)
# Execution of job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:03:34 -05)" skipped: maximum number of running instances reached (1)
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:03:39 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:03:44 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
# ...
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:04 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:09 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:14 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:19 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:24 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:29 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:34 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:39 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# soy otra tarea
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:44 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:49 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:54 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
# Job "di_hola (trigger: interval[0:00:05], next run at: 2020-11-22 11:19:59 -05)" raised an exception
# Traceback (most recent call last):
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\apscheduler\executors\base.py", line 125, in run_job
#     retval = job.func(*job.args, **job.kwargs)
#   File "C:\casa-ortiz\django\smartnature\logic_fuzzy\fuzzy_logic.py", line 20, in di_hola
#     client.connect(host='192.168.100.254', port=1883)
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 941, in connect
#     return self.reconnect()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 1075, in reconnect
#     sock = self._create_socket_connection()
#   File "C:\casa-ortiz\django\smartnature\venv\lib\site-packages\paho\mqtt\client.py", line 3546, in _create_socket_connection
#     return socket.create_connection(addr, source_address=source, timeout=self._keepalive)
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 808, in create_connection
#     raise err
#   File "c:\users\jorge\appdata\local\programs\python\python38\lib\socket.py", line 796, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
